# %% [markdown]
# <a href="https://colab.research.google.com/github/PetrV11/Sechenov/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0%20%D0%9C%D0%BE%D0%B4%D1%83%D0%BB%D1%8C%201%20%D0%92%D0%B2%D0%BE%D0%B4-%D0%92%D1%8B%D0%B2%D0%BE%D0%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# задание 1
print('Hello Word')

# задание 2 ТРИ ВАРИАНТА Датчики температуры
print ("------ВАРИАНТ КОДА 1---------------")
print('4 8 15 16 23 42')
print ("------ВАРИАНТ КОДА 2---------------")
print('4','8','15','16','23','42')
print ("------ВАРИАНТ КОДА 3---------------")
print('4','','8','', '15','', '16','', '23','', '42')

# задание 3
for i in range(8):
    print("*"*i)

# задание 4
dohod = (1200000, 1350000, 1280000, 1420000)
print('Отчёт о доходах')
for i in range(4):
       print(i+1, 'квартал:', dohod[i], 'руб.')

# задание 5
name = input("Здравствуйте, как вас зовут?")
print('Добро пожаловать в команду,', name)

# задание 6
name = input("Введите название компании")
print(name, '-лидер рынка!')

# задание 7
name = input("Введите название набора данных Sales Q1   ")
strok = input( "Введите количество строк 1000   ")
stolb = input( "Введите количество столбцов 8   ")
# задание 7 результат вариант 1
print ("------ВАРИАНТ КОДА 1---------------")
print(f"Name: {name}\nStrok: {strok}\nStolb: {stolb}")
# задание 7 результат вариант 2
print ("-----ВАРИАНТ КОДА 2----------------")
print(f"{name}\n{strok}\n{stolb}")


# задание 8
kvartal01 = dict(otchet01="Продажи за январь",otchet02="Продажи за февраль", otchet03="Продажи за март")
#for keys,values in kvartal01.items():
#   print(keys)
#   print(values)
kvartal01_NEW = list(kvartal01.items())
#print(kvartal01_NEW)
kv = kvartal01_NEW.reverse()
#print(kv)
print ("ВАРИАНТ КОДА 1")
print(kvartal01_NEW[0][1])
print(kvartal01_NEW[1][1])
print(kvartal01_NEW[2][1])
print ("ВАРИАНТ КОДА 2")
#print(f"{kvartal01_NEW[0][1]}\n{kvartal01_NEW[1][1]}")  #РАБОТАЕТ
print(f"{kvartal01_NEW[0][1]}\n{kvartal01_NEW[1][1]}\n{kvartal01_NEW[2][1]}")



# задание 9
base_price = 100
growth_percent = 20
new_price = base_price + base_price/100*growth_percent
delta = new_price - base_price
print("new_price =", new_price)
print("delta =", delta)


# задание 10
print("Северный", "Центральный", "Южный", sep='***')


# задание 11
name = input("введите ваше имя  ")
#print("Подключение установлено.Добро пожаловать,", name, end="!" )
print("Подключение установлено.", end=" ")
print("Добро пожаловать,", name, "!")

# задание 12
print("Молоко", "Хлеб", "Сыр", sep="|")


# задание 13
value_str = "42.7"
print("integer_part ", int(float(value_str)))


# задание 14
orders_yesterday = 10
plan = 20
print("Абсолютное отклонение от плана равняется ", abs(orders_yesterday - plan))

# задание 15
numbers = []
for _ in range(5):
    num = int(input("введите целое число  ", ))
    numbers.append(num)
min_num = min(numbers)
max_num = max(numbers)
print(f"Наименьшее число = {min_num}")
print(f"Наибольшее число = {max_num}")


# задание 16
name = input("Назовите ваше имя  ")
fam = input("Назовите вашу фамилию  ")
print("Привет, ", name, " ", fam, "! ", "Вы только что начали изучать Python")



# задание 17
print("ПОВТОРИТЕ ВВОД ПО ПОДСКАЗКАМ")
zit1 = input("ВВЕДИТЕ 1-ую. ЧАСТЬ цитаты: Каждый в этой стране должен научиться программировать, ")
zit2 = input("ВВЕДИТЕ 2-ую ЧАСТЬ цитаты: потому что это учит думать. ")
print("«", zit1, zit2, "»")



# задание 18
summa_pokupki = int(input(" ВВЕДИТЕ СУММУ ПОКУПКИ "))
print( summa_pokupki > 1000)

# задание 19
vozrast = int(input(" ВВЕДИТЕ ВОЗРАСТ "))
print( vozrast > 18)


# задание 20
vol = 500
vel01 = 50
vel02 = 70
print(vol/(vel01+vel02))

# задание 21
a = 443
b = 390
print("Площадь треугольника " , a*b/2)


# задание 22
t_far = 450.55
print( 5/9*(t_far - 32))


# задание 23
revenue_str = (438746.78)
courier_name = ("Антон")
bonus = float(revenue_str)/100
print( "курьер ", courier_name, "получит бонус ", int(float(revenue_str)/100), "р.")
# Out:
# Hello Word
# ------ВАРИАНТ КОДА 1---------------
# 4 8 15 16 23 42
# ------ВАРИАНТ КОДА 2---------------
# 4 8 15 16 23 42
# ------ВАРИАНТ КОДА 3---------------
# 4  8  15  16  23  42
#
# *
# **
# ***
# ****
# *****
# ******
# *******
# Отчёт о доходах
# 1 квартал: 1200000 руб.
# 2 квартал: 1350000 руб.
# 3 квартал: 1280000 руб.
# 4 квартал: 1420000 руб.
# Здравствуйте, как вас зовут?Влад
# Добро пожаловать в команду, Влад
# Введите название компанииСБЕР
# СБЕР -лидер рынка!
# Введите название набора данных Sales Q1   Sales Q1
# Введите количество строк 1000   1000
# Введите количество столбцов 8   8
# ------ВАРИАНТ КОДА 1---------------
# Name: Sales Q1
# Strok: 1000
# Stolb: 8
# -----ВАРИАНТ КОДА 2----------------
# Sales Q1
# 1000
# 8
# ВАРИАНТ КОДА 1
# Продажи за март
# Продажи за февраль
# Продажи за январь
# ВАРИАНТ КОДА 2
# Продажи за март
# Продажи за февраль
# Продажи за январь
# new_price = 120.0
# delta = 20.0
# Северный***Центральный***Южный
# введите ваше имя  Влад
# ...
